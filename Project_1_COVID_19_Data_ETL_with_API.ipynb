# %% [markdown]
# <a href="https://colab.research.google.com/github/BENMEZIAN/ETL-projects/blob/main/Project_1_COVID_19_Data_ETL_with_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# Step 1: Extract
url = "https://disease.sh/v3/covid-19/countries"
response = requests.get(url)
data = response.json()

# Step 2: Transform
df = pd.json_normalize(data)
df = df[['country', 'cases', 'deaths', 'population']]
df.dropna(inplace=True)
df['cases_per_million'] = df['cases'] / (df['population'] / 1_000_000)

# Step 3: Load (Save to CSV)
df.to_csv('covid_data.csv', index=False)

print("✅ Data saved to covid_data.csv")
# Out:
# ✅ Data saved to covid_data.csv

# %%
df.head()
# Out:
#        country   cases  deaths  population  cases_per_million
# 0  Afghanistan  234174    7996    40754388        5745.982494
# 1      Albania  334863    3605     2866374      116824.601395
# 2      Algeria  272010    6881    45350148        5997.995861
# 3      Andorra   48015     165       77463      619844.312769
# 4       Angola  107327    1937    35027343        3064.091958
